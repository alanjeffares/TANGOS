# %%
# science plots requirements
# !apt-get update
# !sudo apt-get install dvipng texlive-latex-extra texlive-fonts-recommended cm-super
# !pip install SciencePlots
import matplotlib.pyplot as plt
plt.style.reload_library()
import scienceplots
plt.style.use('science')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

green = plt.cm.Greens(0.2*(6/4) + 0.4)
blue = plt.cm.Blues(0.2*(6/4) + 0.4)
red = plt.cm.Reds(0.2*(6/4) + 0.4)

# %%
# import results from running experiment

# 100%
baseline_100 = [0.7938681852038733, 0.8438453590907998, 0.8452870083375381, 0.8704558014368438, 0.8303178836589058, 0.8283836709195319]
tangos_100_01_001 = [0.8185804560417117, 0.8745164468151565, 0.8724020279199404, 0.8740719382974123, 0.8302458011965689, 0.8529157356015281]
tangos_100_1_001 = [0.8749609553329009, 0.8818328167423533, 0.8701794853312189, 0.8748288041519499, 0.8643888608568202, 0.866923760782335, 0.8707441312861914, 0.8726783440255652, 0.8739998558350753, 0.8784209135250727]
tangos_100_1_01 = [0.8745284605588793, 0.8683533962853505, 0.8819289266921359, 0.8598837069607631, 0.8668516783199981, 0.8717412720151854, 0.8685336024411927, 0.8712366947788269, 0.8509935366058772, 0.8752612989259713]
tangos_100_10_01 =  [0.8430884932362623, 0.8443499363271583, 0.8637040774646195, 0.8509454816309858, 0.846091929166967, 0.8488671039669382]
l2_100_0001 = [0.8243830942598332, 0.8243470530286648, 0.8291645642615152, 0.8152526490304909, 0.8276988875273312, 0.8106273576972056]
l2_100_00001 = [0.8551983469088638, 0.8606525865590235, 0.8462601215790865, 0.8472933035392489, 0.8095701482495975, 0.8546096734664456]

# 50%
baseline_50 = [0.8329849347653716, 0.8436891804224033, 0.8292847016987434, 0.8308224608952642, 0.7998990845527283, 0.8213796583291285, 0.8433407818544415, 0.8020615584228358, 0.8309305845887696, 0.8337297868761864]
tangos_50_01_001 = 0
tangos_50_1_001 = [0.8376102260986569, 0.852663446983349, 0.8521708834907133, 0.8347629688363488, 0.8442057714024844, 0.8559311852759557, 0.8563516663062544, 0.850404863163459, 0.8388356279583844, 0.8507172205002523]
tangos_50_1_01 = [0.8345707489367837, 0.8506451380379154, 0.8495639011028616, 0.8450106922319133, 0.8319517528052092, 0.8535764915062832, 0.8432807131358274, 0.8593310747495134, 0.8638001874144021, 0.8491314063288402]
tangos_50_10_01 = [0.8273745164468151, 0.844962637257022, 0.839592493812922, 0.837994665897787, 0.8154568826737788, 0.83932819145102, 0.8197337754391023, 0.8377063360484394, 0.8427881496431918, 0.8242629568226051]
l2_50_0001 = [0.7972800884211538, 0.8199980778010043, 0.8190129508157332, 0.7943727624402316, 0.8134385737283453, 0.8265455681299406]
l2_50_00001 = [0.8116124846824767, 0.8258848122251856, 0.8304620485835796, 0.8325764674787958, 0.836408851726375, 0.8296210865229823]

# 10%
baseline_10 = [0.7147216415579423, 0.7564093322761238, 0.7599654004180783, 0.7611547610466374, 0.7522285494605829, 0.7650832552439991]
tangos_10_01_001 = [0.7307479756841827, 0.7663446983348952, 0.7707177010500011, 0.739157596290156, 0.7598332492371273, 0.7612148297652515]
tangos_10_1_001 = [0.7686753646171219, 0.7795237751988274, 0.7910089141978424, 0.7861793892212692, 0.7710420721305173, 0.7725317763521469]
tangos_10_1_01 = [0.7696244503712247, 0.7747182777096999, 0.7838367091953194, 0.7832960907277926, 0.7724116389149187, 0.7763881880871717]
tangos_10_10_01 = [0.6477810615343953, 0.6643840553593311, 0.6712318892813378, 0.7007977125831951, 0.7037891347701771, 0.6531271774910498]
l2_10_0001 = [0.724164444124078, 0.7326701746798338, 0.7687955020543502, 0.7633172349167447, 0.7721353228092939, 0.7474831206900694]
l2_10_00001 = [0.75852375117134, 0.7574425142362863, 0.7581032701410414, 0.7582954900406065, 0.7688435570292415, 0.7491169898363728]

# 1%
baseline_1 = [0.36950671568274107, 0.41326077032124753, 0.40083855931185275, 0.33124294192556286, 0.38702275403061104, 0.4162281650207838]
tangos_1_01_001 = [0.3709363511857565, 0.4266681083159134, 0.4114707225065475, 0.4235445349479805, 0.40324130805641656, 0.4328191451019967]
tangos_1_1_001 = [0.4338523270621591, 0.47048223167303393, 0.4696893245873279, 0.44059203729066054, 0.4508758019173935, 0.47936038828419714]
tangos_1_1_01 = [0.4623369134289627, 0.4660131190081453, 0.47812297268074677, 0.44539753477978805, 0.4559936567433143, 0.4837934597179173]
tangos_1_10_01 = [0.4090799875057065, 0.4479444484490257, 0.40730195343472936, 0.400093707201038, 0.4010307792114179, 0.443943871789327]
l2_1_0001 = [0.4130565366779596, 0.4592133400610298, 0.42073331891684085, 0.40505538335856217, 0.41335688027103007, 0.4399793363607967]
l2_1_00001 = [0.4049112184338884, 0.41405367740695354, 0.4027127033326125, 0.3308464883827098, 0.3908911795093587, 0.4233042600735241]

# %%
# make plot of performance w.r.t. ratio of data used
baselines_ls = [baseline_1, baseline_10, baseline_50, baseline_100]
tangos_01_001_ls = [tangos_1_01_001, tangos_10_01_001,tangos_50_01_001, tangos_100_01_001]
tangos_1_01_ls = [tangos_1_1_01, tangos_10_1_01,tangos_50_1_01, tangos_100_1_01]
tangos_1_001_ls = [tangos_1_1_001, tangos_10_1_001,tangos_50_1_001, tangos_100_1_001]
tangos_10_01_ls = [tangos_1_10_01, tangos_10_10_01,tangos_50_10_01, tangos_100_10_01]
l2_00001_ls = [l2_1_00001, l2_10_00001, l2_50_00001, l2_100_00001]
l2_0001_ls = [l2_1_0001, l2_10_0001, l2_50_0001, l2_100_0001]



data_dict = {'Baseline': baselines_ls,
            'TANGOS': tangos_1_001_ls,
            'L2': l2_00001_ls}

col_dict = {'Baseline': 'dimgrey',
            'TANGOS': blue,
            'L2': green}


fontsize = 20
fs_legend = 17
plt.figure(figsize=(10,5))
# plt.title('Dionis')
plt.ylabel('\% Test Accuracy', fontsize=fontsize)
plt.xlabel('\% Training Data Used', fontsize=fontsize)
x_vals = [0, 50, 100]
plt.xticks(x_vals, ['10', '50', '100'], fontsize=fontsize)
y_vals = [0.76, 0.8, 0.84, 0.88]
plt.yticks(y_vals, [76, 80, 84, 88], fontsize=fontsize)
plt.ylim(0.76-0.01, 0.88+0.005)
for method, results in data_dict.items():
  results = [proportion[:6] for proportion in results]  # all should have equal runs
  means = [np.mean(proportion) for proportion in results]
  stds = [np.std(proportion) for proportion in results]
  means = means[1:]
  stds = stds[1:]
  upper = [m + s for m, s in zip(means, stds)]
  lower = [m - s for m, s in zip(means, stds)]
  # x_vals = [10, 50, 100]
  if method != 'Baseline':
    plt.plot(x_vals, means, c=col_dict[method], label=method, linewidth=3.5, linestyle='-', marker='s',)
    plt.fill_between(x_vals, upper, lower, color=col_dict[method],
                      alpha=0.25)
  else:
    plt.plot(x_vals, means, c=col_dict[method], label=method, linewidth=3.5, linestyle='-')
handles, labels = plt.gca().get_legend_handles_labels()
order = [1,2,0]
lgnd = plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order], fontsize=fs_legend, frameon=False)
for handle in lgnd.legendHandles:
    handle.set_linewidth(5)
plt.savefig('scale.pdf', format='pdf', dpi=1200)
plt.show()

# %%
baselines_ls = [baseline_1, baseline_10, baseline_50, baseline_100]
tangos_01_001_ls = [tangos_1_01_001, tangos_10_01_001,tangos_50_01_001, tangos_100_01_001]
tangos_1_01_ls = [tangos_1_1_01, tangos_10_1_01,tangos_50_1_01, tangos_100_1_01]
tangos_1_001_ls = [tangos_1_1_001, tangos_10_1_001,tangos_50_1_001, tangos_100_1_001]
tangos_10_01_ls = [tangos_1_10_01, tangos_10_10_01,tangos_50_10_01, tangos_100_10_01]
l2_00001_ls = [l2_1_00001, l2_10_00001, l2_50_00001, l2_100_00001]
l2_0001_ls = [l2_1_0001, l2_10_0001, l2_50_0001, l2_100_0001]


data_dict = {'Baseline': baselines_ls,
            'TANGOS': tangos_1_001_ls,
            'L2': l2_00001_ls}

# data_dict = {'baseline': baselines_ls,
#             'tangos': tangos_1_001_ls}

# data_dict = {'L2': l2_00001_ls,
#             'tangos': tangos_1_001_ls}

col_dict = {'Baseline': 'dimgrey',
            'TANGOS': blue,
            'L2': green}


fontsize = 20
fs_legend = 17
plt.figure(figsize=(10,5))
# plt.title('Dionis')
plt.ylabel('\% Test Accuracy', fontsize=fontsize)
plt.xlabel('\% Training Data Used (Log Scale)', fontsize=fontsize)
x_vals = [0, 50, 100]
plt.xticks(x_vals, ['1', '10', '100'], fontsize=fontsize)
y_vals = [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]
plt.yticks(y_vals, [40, 50, 60, 70, 80, 90], fontsize=fontsize)
for method, results in data_dict.items():
  results = [proportion[:6] for proportion in results]  # all should have equal runs
  means = [np.mean(proportion) for proportion in results]
  stds = [np.std(proportion) for proportion in results]
  means = means[:2] + means[3:]
  stds = stds[:2] + stds[3:]
  upper = [m + s for m, s in zip(means, stds)]
  lower = [m - s for m, s in zip(means, stds)]
  if method != 'Baseline':
    plt.plot(x_vals, means, c=col_dict[method], label=method, linewidth=3.5, linestyle='-', marker='s',)
    plt.fill_between(x_vals, upper, lower, color=col_dict[method],
                      alpha=0.25)
  else:
    plt.plot(x_vals, means, c=col_dict[method], label=method, linewidth=3.5, linestyle='-')
handles, labels = plt.gca().get_legend_handles_labels()
order = [1,2,0]
lgnd = plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order], fontsize=fs_legend, frameon=False)
for handle in lgnd.legendHandles:
    handle.set_linewidth(5)
# plt.legend()
plt.show()
